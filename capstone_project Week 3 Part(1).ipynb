# %%
import requests
website_url = requests.get('https://en.wikipedia.org/wiki/Demographics_of_Toronto_neighbourhoods').text

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(website_url,'html')
print(soup)
# Out:
# c:\users\himanshu poddar\appdata\local\programs\python\python36-32\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file c:\users\himanshu poddar\appdata\local\programs\python\python36-32\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Demographics of Toronto neighbourhoods - Wikipedia</title>
# ...

# %%
My_table = soup.find('table',{'class':'wikitable sortable jquery-tablesorter'})
import pandas as pd

# %%
link = "https://en.wikipedia.org/wiki/Demographics_of_Toronto_neighbourhoods"

tables = pd.read_html(link,header=0)[1]
tables
# Out:
#                          Name    FM  \
# 0         Toronto CMA Average   NaN
# 1                   Agincourt     S
# 2                   Alderwood     E
# 3              Alexandra Park  OCoT
# 4                     Allenby  OCoT
# 5                    Amesbury    NY
# 6              Armour Heights    NY
# 7                     Banbury    NY
# 8              Bathurst Manor    NY
# 9         Bay Street Corridor  OCoT
# 10            Bayview Village    NY
# 11    Bayview Woods – Steeles    NY
# 12               Bedford Park  OCoT
# 13                    Bendale     S
# 14                Birch Cliff     S
# 15         Bloor West Village  OCoT
# 16            Bracondale Hill  OCoT
# 17                    Branson    NY
# 18                Bridle Path    NY
# 19                   Brockton  OCoT
# 20                Cabbagetown  OCoT
# 21               Caribou Park    NY
# 22           Carleton Village  OCoT
# 23                  Casa Loma  OCoT
# 24                 Centennial     E
# ...
